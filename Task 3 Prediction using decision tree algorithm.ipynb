# %% [markdown]
# **TASK-3 Prediction using Decision Tree Algorithm
# BY- KARTIKEY GUPTA**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
iris_data=datasets.load_iris()
A=iris_data.data
B=iris_data.target

# %%
A_train, A_test, B_train, B_test = train_test_split(A, B, test_size=0.20)

# %%
dtc=DecisionTreeClassifier(random_state=1)
dtc_model=dtc.fit(A_train,B_train)

# %%
_ = tree.plot_tree(dtc,feature_names=iris_data.feature_names,class_names=iris_data.target_names,filled=True)

# %%
text_representation = tree.export_text(dtc)
print(text_representation)
# Out:
# |--- feature_3 <= 0.70
# |   |--- class: 0
# |--- feature_3 >  0.70
# |   |--- feature_2 <= 4.75
# |   |   |--- feature_3 <= 1.65
# |   |   |   |--- class: 1
# |   |   |--- feature_3 >  1.65
# |   |   |   |--- class: 2
# |   |--- feature_2 >  4.75
# |   |   |--- feature_3 <= 1.70
# |   |   |   |--- feature_2 <= 4.95
# |   |   |   |   |--- class: 1
# |   |   |   |--- feature_2 >  4.95
# |   |   |   |   |--- feature_3 <= 1.55
# |   |   |   |   |   |--- class: 2
# |   |   |   |   |--- feature_3 >  1.55
# |   |   |   |   |   |--- feature_2 <= 5.45
# |   |   |   |   |   |   |--- class: 1
# |   |   |   |   |   |--- feature_2 >  5.45
# |   |   |   |   |   |   |--- class: 2
# |   |   |--- feature_3 >  1.70
# |   |   |   |--- feature_2 <= 4.85
# |   |   |   |   |--- feature_0 <= 5.95
# |   |   |   |   |   |--- class: 1
# |   |   |   |   |--- feature_0 >  5.95
# |   |   |   |   |   |--- class: 2
# |   |   |   |--- feature_2 >  4.85
# |   |   |   |   |--- class: 2

# %%
B_pred=dtc_model.predict(A_test)

# %%
print(confusion_matrix(A_test, B_pred))
print(classification_report(B_test, B_pred))
# Out:
# [[5 0 0]
#  [0 5 0]
#  [0 1 4]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         5
#            1       0.83      1.00      0.91         5
#            2       1.00      0.80      0.89         5
#
#     accuracy                           0.93        15
#    macro avg       0.94      0.93      0.93        15
# weighted avg       0.94      0.93      0.93        15
